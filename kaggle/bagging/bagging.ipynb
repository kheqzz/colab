# %%
import joblib

# Alur path default Kaggle: /kaggle/input/{nama-dataset-kamu}/{nama-file}
KAGGLE_PATH = '/kaggle/input/datasets/hanifsaifuddin/dataset-with-more-x-variabels/'

print("=== MEMUAT DATA & MODEL DARI INPUT KAGGLE ===")

# 1. Load Data Preprocessing
X_train_resampled = joblib.load(KAGGLE_PATH + 'X_train_resampled_values_v1.pkl')
y_train_resampled = joblib.load(KAGGLE_PATH + 'y_train_resampled_values_v1.pkl')
X_test = joblib.load(KAGGLE_PATH + 'X_test_values_v1.pkl')
y_test = joblib.load(KAGGLE_PATH + 'y_test_values_v1.pkl')

# 2. Load Base Learners yang sudah pintar dari lokal
loaded_dt = joblib.load(KAGGLE_PATH + 'dt_model_v1.pkl')
loaded_lr = joblib.load(KAGGLE_PATH + 'lr_model_v1.pkl')
loaded_nb = joblib.load(KAGGLE_PATH + 'nb_model_v1.pkl')
loaded_rf = joblib.load(KAGGLE_PATH + 'rf_model_v1.pkl')

print("Semua file biner sukses ditarik ke RAM cloud Kaggle! Siap gas bagging.")
# Out:
# === MEMUAT DATA & MODEL DARI INPUT KAGGLE ===
# Semua file biner sukses ditarik ke RAM cloud Kaggle! Siap gas bagging.

# %%
import joblib
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score,recall_score,precision_score,f1_score


print('data loaded')
# 2. Definisikan kombinasi Bagging sesuai baris jurnal
bagging_experiments = {
    'Bagging_DT': BaggingClassifier(estimator=loaded_dt, n_estimators=10, random_state=42, n_jobs=-1),
    'Bagging_LR': BaggingClassifier(estimator=loaded_lr, n_estimators=10, random_state=42, n_jobs=-1),
    'Bagging_NB': BaggingClassifier(estimator=loaded_nb, n_estimators=10, random_state=42, n_jobs=-1),
    'Bagging_RF': BaggingClassifier(estimator=loaded_rf, n_estimators=10, random_state=42, n_jobs=-1)
}

# 3. Loop Training & Evaluasi langsung
print("=== EKSPERIMEN BAGGING ===")
for name, model in bagging_experiments.items():
    model.fit(X_train_resampled, y_train_resampled)
    preds = model.predict(X_test)
    print(f"Model: {name}")
    print(classification_report(y_test, preds))

    print(f"=========== Hasil dari {name} =============\n")
    print(f"{name} Confusion Matrix: {confusion_matrix(y_test, preds)}\n")
    

    print(f"{name} Accuracy Score: {accuracy_score(y_test, preds):.4f}\n")
    

    print(f"{name} Recall Score: {recall_score(y_test, preds):.4f}\n")
   

    print(f"{name}Precision Score: {precision_score(y_test, preds):.4f}\n")
   
    print(f"{name} | F1-Score: {f1_score(y_test, preds):.4f}")
    
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
        auc_score = roc_auc_score(y_test, y_proba)
        print(f"AUC-ROC Score: {auc_score:.4f}")
    
   
    joblib.dump(model, f'{name}_final.pkl')
# Out:
# data loaded
# === EKSPERIMEN BAGGING ===
# Model: Bagging_DT
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906351
#            1       0.90      0.88      0.89      2435
#
#     accuracy                           1.00   1908786
#    macro avg       0.95      0.94      0.94   1908786
# weighted avg       1.00      1.00      1.00   1908786
#
# =========== Hasil dari Bagging_DT =============
#
# Bagging_DT Confusion Matrix: [[1906099     252]
#  [    287    2148]]
#
# Bagging_DT Accuracy Score: 0.9997
#
# Bagging_DT Recall Score: 0.8821
#
# Bagging_DTPrecision Score: 0.8950
#
# Bagging_DT | F1-Score: 0.8885
# AUC-ROC Score: 0.9790
# Model: Bagging_LR
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98   1906351
#            1       0.03      0.91      0.05      2435
#
#     accuracy                           0.96   1908786
#    macro avg       0.51      0.93      0.51   1908786
# weighted avg       1.00      0.96      0.98   1908786
#
# =========== Hasil dari Bagging_LR =============
#
# Bagging_LR Confusion Matrix: [[1821382   84969]
#  [    210    2225]]
#
# Bagging_LR Accuracy Score: 0.9554
#
# Bagging_LR Recall Score: 0.9138
#
# Bagging_LRPrecision Score: 0.0255
#
# Bagging_LR | F1-Score: 0.0496
# AUC-ROC Score: 0.9869
# Model: Bagging_NB
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99   1906351
#            1       0.02      0.30      0.03      2435
#
#     accuracy                           0.97   1908786
#    macro avg       0.51      0.64      0.51   1908786
# weighted avg       1.00      0.97      0.99   1908786
#
# =========== Hasil dari Bagging_NB =============
#
# Bagging_NB Confusion Matrix: [[1859538   46813]
#  [   1712     723]]
#
# Bagging_NB Accuracy Score: 0.9746
#
# Bagging_NB Recall Score: 0.2969
#
# Bagging_NBPrecision Score: 0.0152
#
# Bagging_NB | F1-Score: 0.0289
# AUC-ROC Score: 0.7984
# Model: Bagging_RF
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906351
#            1       0.89      0.85      0.87      2435
#
#     accuracy                           1.00   1908786
#    macro avg       0.94      0.92      0.93   1908786
# weighted avg       1.00      1.00      1.00   1908786
#
# =========== Hasil dari Bagging_RF =============
#
# Bagging_RF Confusion Matrix: [[1906090     261]
#  [    366    2069]]
#
# Bagging_RF Accuracy Score: 0.9997
#
# Bagging_RF Recall Score: 0.8497
#
# Bagging_RFPrecision Score: 0.8880
#
# Bagging_RF | F1-Score: 0.8684
# AUC-ROC Score: 0.9976
