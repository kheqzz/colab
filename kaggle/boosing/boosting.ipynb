# %%
import joblib
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score,recall_score,precision_score,f1_score

path = "/kaggle/input/datasets/hanifsaifuddin/dataset-with-more-x-variabels/"
# (Pastikan baris load pkl data & model dasar sama seperti di atas)
X_train_resampled = joblib.load(path+'X_train_resampled_values_v1.pkl')
y_train_resampled = joblib.load(path+'y_train_resampled_values_v1.pkl')
X_test = joblib.load(path+'X_test_values_v1.pkl')
y_test = joblib.load(path+'y_test_values_v1.pkl')

loaded_dt = joblib.load(path+'dt_model_v1.pkl')
loaded_lr = joblib.load(path+'lr_model_v1.pkl')
loaded_nb = joblib.load(path+'nb_model_v1.pkl')
loaded_rf = joblib.load(path+'rf_model_v1.pkl')
# Definisikan kombinasi Boosting sesuai baris jurnal
boosting_experiments = {
    'Boosting_DT': AdaBoostClassifier(estimator=loaded_dt, n_estimators=50, random_state=42),
    'Boosting_LR': AdaBoostClassifier(estimator=loaded_lr, n_estimators=50, random_state=42),
    'Boosting_NB': AdaBoostClassifier(estimator=loaded_nb, n_estimators=50, random_state=42),
    'Boosting_RF': AdaBoostClassifier(estimator=loaded_rf, n_estimators=50, random_state=42)
}

print("=== EKSPERIMEN BOOSTING (LOKAL) ===")
for name, model in boosting_experiments.items():
    model.fit(X_train_resampled, y_train_resampled)
    preds = model.predict(X_test)
    print(f"Model: {name}")
    print(classification_report(y_test, preds))

    print(f"=========== Hasil dari {name} =============\n")
    print(f"{name} Confusion Matrix: {confusion_matrix(y_test, preds)}\n")
    

    print(f"{name} Accuracy Score: {accuracy_score(y_test, preds):.4f}\n")
    

    print(f"{name} Recall Score: {recall_score(y_test, preds):.4f}\n")
   

    print(f"{name}Precision Score: {precision_score(y_test, preds):.4f}\n")
   
    print(f"{name} | F1-Score: {f1_score(y_test, preds):.4f}\n")
    
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
        auc_score = roc_auc_score(y_test, y_proba)
        print(f"AUC-ROC Score: {auc_score:.4f}\n")
    
    
    joblib.dump(model, f'{name}_final.pkl')
# Out:
# === EKSPERIMEN BOOSTING (LOKAL) ===
# Model: Boosting_DT
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906351
#            1       0.89      0.87      0.88      2435
#
#     accuracy                           1.00   1908786
#    macro avg       0.95      0.93      0.94   1908786
# weighted avg       1.00      1.00      1.00   1908786
#
# =========== Hasil dari Boosting_DT =============
#
# Boosting_DT Confusion Matrix: [[1906102     249]
#  [    318    2117]]
#
# Boosting_DT Accuracy Score: 0.9997
#
# Boosting_DT Recall Score: 0.8694
#
# Boosting_DTPrecision Score: 0.8948
#
# Boosting_DT | F1-Score: 0.8819
#
# AUC-ROC Score: 0.9346
#
# Model: Boosting_LR
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98   1906351
#            1       0.03      0.85      0.05      2435
#
#     accuracy                           0.96   1908786
#    macro avg       0.51      0.91      0.52   1908786
# weighted avg       1.00      0.96      0.98   1908786
#
# =========== Hasil dari Boosting_LR =============
#
# Boosting_LR Confusion Matrix: [[1834784   71567]
#  [    363    2072]]
#
# Boosting_LR Accuracy Score: 0.9623
#
# Boosting_LR Recall Score: 0.8509
#
# Boosting_LRPrecision Score: 0.0281
#
# Boosting_LR | F1-Score: 0.0545
#
# AUC-ROC Score: 0.9818
#
# Model: Boosting_NB
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98   1906351
#            1       0.02      0.49      0.03      2435
#
#     accuracy                           0.96   1908786
#    macro avg       0.51      0.73      0.50   1908786
# weighted avg       1.00      0.96      0.98   1908786
#
# =========== Hasil dari Boosting_NB =============
#
# Boosting_NB Confusion Matrix: [[1830596   75755]
#  [   1236    1199]]
#
# Boosting_NB Accuracy Score: 0.9597
#
# Boosting_NB Recall Score: 0.4924
#
# Boosting_NBPrecision Score: 0.0156
#
# Boosting_NB | F1-Score: 0.0302
#
# AUC-ROC Score: 0.7595
#
# Model: Boosting_RF
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906351
#            1       0.92      0.83      0.87      2435
#
#     accuracy                           1.00   1908786
#    macro avg       0.96      0.91      0.93   1908786
# weighted avg       1.00      1.00      1.00   1908786
#
# =========== Hasil dari Boosting_RF =============
#
# Boosting_RF Confusion Matrix: [[1906165     186]
#  [    420    2015]]
#
# Boosting_RF Accuracy Score: 0.9997
#
# Boosting_RF Recall Score: 0.8275
#
# Boosting_RFPrecision Score: 0.9155
#
# Boosting_RF | F1-Score: 0.8693
#
# AUC-ROC Score: 0.9137
